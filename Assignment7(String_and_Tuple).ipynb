# %%
String1= "Hello"
String2= "Zara"
print(String1+ " " +String2)
# Out:
# Hello Zara

# %%
String3= "welcome to Python programming"
print(String1 + " " + String2 + ","+ " " + String3)
# Out:
# Hello Zara, welcome to Python programming

# %%
String= "Hello Zara, welcome to Python programming"
print(String)
print(String[0])
print(String[-1])
print(String[0:5])
print(String[30:42])
print(String[::-1])
print(String[23:29])
# Out:
# Hello Zara, welcome to Python programming
# H
# g
# Hello
# programming
# gnimmargorp nohtyP ot emoclew ,araZ olleH
# Python

# %%
strM = "Python beginner tutorial"
print(strM)
print(strM.upper())
print(strM.lower())
print(strM.capitalize())
print(strM.count('t'))
print(strM.replace("Python beginner tutorial", "Machine Learning beginner tutorial"))
# Out:
# Python beginner tutorial
# PYTHON BEGINNER TUTORIAL
# python beginner tutorial
# Python beginner tutorial
# 3
# Machine Learning beginner tutorial

# %%
t1= (10, 20, 30)
t2= (40, 50, 60)
t_combine= t1 + t2
print(t_combine)
print(t_combine *3)
print(t_combine[2])
print(t_combine[0:3])
print(t_combine[3:6])
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 30
# (10, 20, 30)
# (40, 50, 60)
